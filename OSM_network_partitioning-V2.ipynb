# %% [markdown]
# # Open Street Map network partitioning
# ---

# %% [markdown]
# ## Imports

# %%
import networkx as nx
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import osmnx as ox
from networkx.algorithms import community
import community as louvain
import matplotlib.cm as cm
import matplotlib.colors as mpcol
from matplotlib.colors import LinearSegmentedColormap
#import geopandas as gpd
from descartes import PolygonPatch
from shapely.geometry import Polygon, MultiPolygon
from operator import itemgetter
from haversine import haversine, Unit
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
import math
from itertools import islice

# %matplotlib inline

# %%
ox.config(data_folder='data', logs_folder='logs', 
          imgs_folder='imgs', cache_folder='cache', 
          use_cache=True, log_file=True, log_console=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6bb8640f4693> in <module>
# ----> 1 ox.config(data_folder='data', logs_folder='logs',
#       2           imgs_folder='imgs', cache_folder='cache',
#       3           use_cache=True, log_file=True, log_console=True)
#
# NameError: name 'ox' is not defined

# %% [markdown]
# # Download the data - write to pickle

# %%
#G_drive = ox.graph_from_place('Greater Manchester, UK', network_type='drive', simplify=True, which_result=2)
#G_drive = ox.project_graph(G_drive)

# %%
#nx.write_gpickle(G_drive, "pickle/OSM_street_network.gpickle")

# %%
G_drive = nx.read_gpickle("pickle/OSM_street_network.gpickle")

# %%
G_drive

# %% [markdown]
# ## Undirected network

# %%
def undirected_network(G):
    G_simple = nx.Graph()
    for i,j,data in G.edges(data=True):
        w = data['weight'] if 'weight' in data else 1.0
        if G_simple.has_edge(i,j):
            G_simple[i][j]['weight'] += w
        else:
            G_simple.add_edge(i,j,weight=w)
    return G_simple

# %%
G_simple = undirected_network(G_drive)

# %% [markdown]
# # Partitioning the graph into geographical chunks

# %%
G = nx.Graph(G_drive)
G

# %%
list(G.nodes(data=True))[0]
# Out:
# (398721038,
#  {'y': 5927330.199041799,
#   'x': 529715.0012583488,
#   'osmid': 398721038,
#   'highway': nan,
#   'ref': nan,
#   'lon': -2.5520905,
#   'lat': 53.4940952})

# %%
list(G.nodes(data=True))[0][1]
# Out:
# {'y': 5927330.199041799,
#  'x': 529715.0012583488,
#  'osmid': 398721038,
#  'highway': nan,
#  'ref': nan,
#  'lon': -2.5520905,
#  'lat': 53.4940952}

# %%
# get lat long
(list(G.nodes(data=True))[0][1]['lon'], list(G.nodes(data=True))[0][1]['lat'])
# Out:
# (-2.5520905, 53.4940952)

# %%
# get tuple of x/y coordinates

locations = []

for node in G.nodes():
    locations.append(tuple([(G.nodes[node]['lon']), G.nodes[node]['lat']]))

# %%
locations[0]
# Out:
# (-2.5520905, 53.4940952)

# %%
# get min/max coordinates
min_x = min(locations,key=itemgetter(0))[0]
max_x = max(locations,key=itemgetter(0))[0]
min_y = min(locations,key=itemgetter(1))[1]
max_y = max(locations,key=itemgetter(1))[1]

# %%
min_x
# Out:
# -2.7171539

# %%
max_x
# Out:
# -1.9774292

# %%
min_y
# Out:
# 53.3426582

# %%
max_y
# Out:
# 53.6643887

# %%
# get corners of rectangle
sw = tuple([min_x, min_y])
nw = tuple([min_x, max_y])
ne = tuple([max_x, max_y])
se = tuple([max_x, min_y])

# %%
print(nw)
print(sw)
print(ne)
print(se)
# Out:
# (-2.7171539, 53.6643887)
# (-2.7171539, 53.3426582)
# (-1.9774292, 53.6643887)
# (-1.9774292, 53.3426582)

# %%
# find length of sides
#length = haversine(sw, nw, Unit.KILOMETERS)
#print(length)
#width = haversine(sw, se, Unit.KILOMETERS)
#print(width)

# %%
#length*width

# %%
def getEquidistantPoints(p1, p2, parts):
    return zip(np.linspace(p1[0], p2[0], parts+1),
               np.linspace(p1[1], p2[1], parts+1))

# %%
# list(getEquidistantPoints((nw), (sw), 5))

# %%
# list(getEquidistantPoints((sw), (se), 5))

# %%
y = list(getEquidistantPoints((nw), (sw), 26))
x = list(getEquidistantPoints((sw), (se), 26))

# %%
y
# Out:
# [(-2.7171539, 53.6643887),
#  (-2.7171539, 53.65201445),
#  (-2.7171539, 53.6396402),
#  (-2.7171539, 53.62726595),
#  (-2.7171539, 53.6148917),
#  (-2.7171539, 53.60251745),
#  (-2.7171539, 53.5901432),
#  (-2.7171539, 53.57776895000001),
#  (-2.7171539, 53.565394700000006),
#  (-2.7171539, 53.553020450000005),
#  (-2.7171539, 53.540646200000005),
#  (-2.7171539, 53.528271950000004),
#  (-2.7171539, 53.515897700000004),
#  (-2.7171539, 53.50352345),
#  (-2.7171539, 53.4911492),
#  (-2.7171539, 53.47877495),
#  (-2.7171539, 53.4664007),
#  (-2.7171539, 53.45402645),
#  (-2.7171539, 53.4416522),
#  (-2.7171539, 53.42927795),
#  (-2.7171539, 53.416903700000006),
#  (-2.7171539, 53.404529450000005),
#  (-2.7171539, 53.392155200000005),
#  (-2.7171539, 53.379780950000004),
#  (-2.7171539, 53.367406700000004),
#  (-2.7171539, 53.35503245),
#  (-2.7171539, 53.3426582)]

# %%
x
# Out:
# [(-2.7171539, 53.3426582),
#  (-2.68870295, 53.3426582),
#  (-2.660252, 53.3426582),
#  (-2.63180105, 53.3426582),
#  (-2.6033501, 53.3426582),
#  (-2.5748991500000002, 53.3426582),
#  (-2.5464482, 53.3426582),
#  (-2.51799725, 53.3426582),
#  (-2.4895463, 53.3426582),
#  (-2.46109535, 53.3426582),
#  (-2.4326444, 53.3426582),
#  (-2.40419345, 53.3426582),
#  (-2.3757425, 53.3426582),
#  (-2.34729155, 53.3426582),
#  (-2.3188406, 53.3426582),
#  (-2.29038965, 53.3426582),
#  (-2.2619387, 53.3426582),
#  (-2.23348775, 53.3426582),
#  (-2.2050368000000002, 53.3426582),
#  (-2.17658585, 53.3426582),
#  (-2.1481349, 53.3426582),
#  (-2.1196839499999998, 53.3426582),
#  (-2.091233, 53.3426582),
#  (-2.06278205, 53.3426582),
#  (-2.0343311, 53.3426582),
#  (-2.0058801500000003, 53.3426582),
#  (-1.9774292, 53.3426582)]

# %%
ys = [x[1] for x in y]

# %%
xs = [x[0] for x in x]

# %%
print(ys)
print(xs)
# Out:
# [53.6643887, 53.65201445, 53.6396402, 53.62726595, 53.6148917, 53.60251745, 53.5901432, 53.57776895000001, 53.565394700000006, 53.553020450000005, 53.540646200000005, 53.528271950000004, 53.515897700000004, 53.50352345, 53.4911492, 53.47877495, 53.4664007, 53.45402645, 53.4416522, 53.42927795, 53.416903700000006, 53.404529450000005, 53.392155200000005, 53.379780950000004, 53.367406700000004, 53.35503245, 53.3426582]
# [-2.7171539, -2.68870295, -2.660252, -2.63180105, -2.6033501, -2.5748991500000002, -2.5464482, -2.51799725, -2.4895463, -2.46109535, -2.4326444, -2.40419345, -2.3757425, -2.34729155, -2.3188406, -2.29038965, -2.2619387, -2.23348775, -2.2050368000000002, -2.17658585, -2.1481349, -2.1196839499999998, -2.091233, -2.06278205, -2.0343311, -2.0058801500000003, -1.9774292]

# %%
X, Y = np.meshgrid(xs, ys)
grid = zip(X, Y)

# %%
plt.plot(X, Y, marker='+', color='red', linestyle='none')
# Out:
# [<matplotlib.lines.Line2D at 0x7fa27cf8b510>,
#  <matplotlib.lines.Line2D at 0x7fa28182a150>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b110>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b6d0>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b410>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b210>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b1d0>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b250>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58c10>,
#  <matplotlib.lines.Line2D at 0x7fa27cf8b310>,
#  <matplotlib.lines.Line2D at 0x7fa27cf589d0>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58890>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58a10>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58410>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58850>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58150>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58ad0>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58d10>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58950>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58c50>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58990>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58590>,
#  <matplotlib.lines.Line2D at 0x7fa27cf584d0>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58390>,
#  <matplotlib.lines.Line2D at 0x7fa27cf58f50>,
#  <matplotlib.lines.Line2D at 0x7fa27cf583d0>,
#  <matplotlib.lines.Line2D at 0x7fa27cf582d0>]

# %%
#X, Y = np.meshgrid(xs, ys)
#grid = zip(X, Y)

# %%
#grid = []

#for y in ys:
#    for x in xs:
#        grid.append(tuple([x,y]))

# %%
#type(grid)

# %%
#grid

# %%
#point = Point(0.5, 0.5)
#polygon = Polygon([(0, 0), (0, 1), (1, 1), (1, 0)])
#print(polygon.contains(point))

# %%
y_square = (max_y - min_y)/100
y_square
# Out:
# 0.00321730500000001

# %%
x_square = (max_x - min_x)/100
x_square
# Out:
# 0.007397247

# %%
#df = pd.DataFrame()

#x_square = (max_x - min_x)/10
#y_square = (max_y - min_y)/10
#square_side = 5
#x_min = df['X[mm]'].min()
#y_min = df['Y[mm]'].min()

#def label_point(x, y):
    # Double forward slash is integer (round down) division
    # Add 1 here if you really want 1-based indexing
#    x_label = (x - min_x) // (x_square)

#    y_label = chr(ord('A') + int((y - min_y) // y_square))
    
#    return f'{x_label}{y_label}'

# %%
df = pd.DataFrame()

x_square = (max_x - min_x)/26
y_square = (max_y - min_y)/26
#square_side = 5
#x_min = df['X[mm]'].min()
#y_min = df['Y[mm]'].min()

def label_point(x, y):
    # Double forward slash is integer (round down) division
    # Add 1 here if you really want 1-based indexing
    x_label = (x - min_x) // (x_square)

    y_label = chr(ord('Z') - int((y - min_y) // y_square))
    
    return f'{x_label}{y_label}'

# %%
print(label_point(nw[0], nw[1]))
print(label_point(ne[0], ne[1]))
print(label_point(sw[0], sw[1]))
print(label_point(se[0], se[1]))
# Out:
# 0.0A
# 26.0A
# 0.0Z
# 26.0Z

# %%
xx = []
for i in locations:
    xx.append(i[0])
    
yy = []
for i in locations:
    yy.append(i[1])

# %%
df['x'] = xx
df['y'] = yy

# %%
chr(ord('A') + int((max_y - min_y) // y_square))
# Out:
# 'Z'

# %%
df['label'] = df[['x', 'y']].apply(lambda coord: label_point(*coord), axis=1)

# %%
df['label'].value_counts()
# Out:
# 16.0O    637
# 9.0G     596
# 17.0O    558
# 16.0P    552
# 16.0N    544
#         ...
# 9.0Q       1
# 17.0B      1
# 14.0Z      1
# 11.0T      1
# 4.0E       1
# Name: label, Length: 470, dtype: int64

# %%
df
# Out:
#               x          y  label
# 0     -2.552090  53.494095   5.0N
# 1     -2.637079  53.558678   2.0I
# 2     -2.541474  53.479011   6.0O
# 3     -2.133602  53.379638  20.0X
# 4     -2.134236  53.378917  20.0X
# ...         ...        ...    ...
# 96248 -2.327129  53.369216  13.0X
# 96249 -2.134148  53.379133  20.0X
# 96250 -2.142255  53.523432  20.0L
# 96251 -2.134107  53.379268  20.0X
# 96252 -2.134252  53.379294  20.0X
#
# [96253 rows x 3 columns]

# %%
res = dict(zip(list(G.nodes()), df['label']))

# %%
#res

# %%
nx.set_node_attributes(G, res, "sub_graph")

# %%
locations = dict(zip(list(G.nodes()), locations))
nx.set_node_attributes(G, locations, 'pos')

# %%
list(G.nodes(data=True))[0]
# Out:
# (398721038,
#  {'y': 5927330.199041799,
#   'x': 529715.0012583488,
#   'osmid': 398721038,
#   'highway': nan,
#   'ref': nan,
#   'lon': -2.5520905,
#   'lat': 53.4940952,
#   'sub_graph': '5.0N',
#   'pos': (-2.5520905, 53.4940952)})

# %%
list(G.nodes(data=True))[10]
# Out:
# (2269904954,
#  {'y': 5914869.262966493,
#   'x': 557626.6518414832,
#   'osmid': 2269904954,
#   'highway': nan,
#   'ref': nan,
#   'lon': -2.1336849,
#   'lat': 53.3797828,
#   'sub_graph': '20.0W',
#   'pos': (-2.1336849, 53.3797828)})

# %%
grid_refs = sorted(df['label'].unique())

# %%
len(grid_refs)
# Out:
# 470

# %%
from itertools import groupby

# Sort the nodes by their role (this is required for the groupby to work)
sorted_by_role = sorted(G.nodes(data=True), key=lambda node_data: node_data[1]["sub_graph"])
# Group objects with same role together
grouped = groupby(sorted_by_role, key=lambda node_data: node_data[1]["sub_graph"])

subgraphs = dict()
for key, group in grouped:
     nodes_in_group, _ = zip(*list(group))  # We don't care about the data here, only the node names
     subgraphs[key] = G.subgraph(nodes_in_group)

# %%
sorted(subgraphs)
# Out:
# ['0.0F',
#  '0.0G',
#  '0.0H',
#  '0.0I',
#  '0.0J',
#  '0.0K',
#  '0.0L',
#  '0.0M',
#  '1.0F',
#  '1.0G',
#  '1.0H',
#  '1.0I',
#  '1.0J',
#  '1.0K',
#  '1.0L',
#  '1.0M',
#  '1.0N',
#  '10.0D',
#  '10.0E',
#  '10.0F',
#  '10.0G',
#  '10.0H',
#  '10.0I',
#  '10.0J',
#  '10.0K',
#  '10.0L',
#  '10.0M',
#  '10.0N',
#  '10.0P',
#  '10.0Q',
#  '10.0R',
#  '10.0S',
#  '10.0T',
#  '10.0U',
#  '10.0V',
#  '10.0W',
#  '11.0C',
#  '11.0D',
#  '11.0E',
#  '11.0F',
#  '11.0G',
#  '11.0H',
#  '11.0I',
#  '11.0J',
#  '11.0K',
#  '11.0L',
#  '11.0M',
#  '11.0N',
#  '11.0O',
#  '11.0P',
#  '11.0Q',
#  '11.0R',
#  '11.0S',
#  '11.0T',
#  '11.0U',
#  '11.0V',
#  '11.0W',
#  '11.0X',
#  '12.0C',
#  '12.0D',
#  '12.0E',
#  '12.0F',
#  '12.0G',
#  '12.0H',
#  '12.0I',
#  '12.0J',
#  '12.0K',
#  '12.0L',
#  '12.0M',
#  '12.0N',
#  '12.0O',
#  '12.0P',
#  '12.0Q',
#  '12.0R',
#  '12.0S',
#  '12.0T',
#  '12.0U',
#  '12.0V',
#  '12.0W',
#  '12.0X',
#  '13.0A',
#  '13.0B',
#  '13.0C',
#  '13.0D',
#  '13.0E',
#  '13.0F',
#  '13.0G',
#  '13.0H',
#  '13.0I',
#  '13.0J',
#  '13.0K',
#  '13.0L',
#  '13.0M',
#  '13.0N',
#  '13.0O',
#  '13.0P',
#  '13.0Q',
#  '13.0R',
#  '13.0S',
#  '13.0T',
#  '13.0U',
#  '13.0V',
#  '13.0W',
#  '13.0X',
#  '13.0Y',
#  '14.0A',
#  '14.0B',
#  '14.0C',
#  '14.0D',
#  '14.0E',
#  '14.0F',
#  '14.0G',
#  '14.0H',
#  '14.0I',
#  '14.0J',
#  '14.0K',
#  '14.0L',
#  '14.0M',
#  '14.0N',
#  '14.0O',
#  '14.0P',
#  '14.0Q',
#  '14.0R',
#  '14.0S',
#  '14.0T',
#  '14.0U',
#  '14.0V',
#  '14.0W',
#  '14.0X',
#  '14.0Y',
#  '14.0Z',
#  '15.0C',
#  '15.0D',
#  '15.0E',
#  '15.0F',
#  '15.0G',
#  '15.0H',
#  '15.0I',
#  '15.0J',
#  '15.0K',
#  '15.0L',
#  '15.0M',
#  '15.0N',
#  '15.0O',
#  '15.0P',
#  '15.0Q',
#  '15.0R',
#  '15.0S',
#  '15.0T',
#  '15.0U',
#  '15.0V',
#  '15.0W',
#  '15.0X',
#  '15.0Y',
#  '16.0C',
#  '16.0D',
#  '16.0E',
#  '16.0F',
#  '16.0G',
#  '16.0H',
#  '16.0I',
#  '16.0J',
#  '16.0K',
#  '16.0L',
#  '16.0M',
#  '16.0N',
#  '16.0O',
#  '16.0P',
#  '16.0Q',
#  '16.0R',
#  '16.0S',
#  '16.0T',
#  '16.0U',
#  '16.0V',
#  '16.0W',
#  '16.0X',
#  '16.0Y',
#  '17.0B',
#  '17.0C',
#  '17.0D',
#  '17.0E',
#  '17.0F',
#  '17.0G',
#  '17.0H',
#  '17.0I',
#  '17.0J',
#  '17.0K',
#  '17.0L',
#  '17.0M',
#  '17.0N',
#  '17.0O',
#  '17.0P',
#  '17.0Q',
#  '17.0R',
#  '17.0S',
#  '17.0T',
#  '17.0U',
#  '17.0V',
#  '17.0W',
#  '17.0X',
#  '17.0Y',
#  '18.0B',
#  '18.0C',
#  '18.0D',
#  '18.0E',
#  '18.0F',
#  '18.0G',
#  '18.0H',
#  '18.0I',
#  '18.0J',
#  '18.0K',
#  '18.0L',
#  '18.0M',
#  '18.0N',
#  '18.0O',
#  '18.0P',
#  '18.0Q',
#  '18.0R',
#  '18.0S',
#  '18.0T',
#  '18.0U',
#  '18.0V',
#  '18.0W',
#  '18.0X',
#  '18.0Y',
#  '18.0Z',
#  '19.0B',
#  '19.0C',
#  '19.0D',
#  '19.0E',
#  '19.0F',
#  '19.0G',
#  '19.0H',
#  '19.0I',
#  '19.0J',
#  '19.0K',
#  '19.0L',
#  '19.0M',
#  '19.0N',
#  '19.0O',
#  '19.0P',
#  '19.0Q',
#  '19.0R',
#  '19.0S',
#  '19.0T',
#  '19.0U',
#  '19.0V',
#  '19.0W',
#  '19.0X',
#  '19.0Y',
#  '19.0Z',
#  '2.0F',
#  '2.0G',
#  '2.0H',
#  '2.0I',
#  '2.0J',
#  '2.0K',
#  '2.0L',
#  '2.0M',
#  '2.0N',
#  '2.0O',
#  '20.0B',
#  '20.0C',
#  '20.0D',
#  '20.0E',
#  '20.0F',
#  '20.0G',
#  '20.0H',
#  '20.0I',
#  '20.0J',
#  '20.0K',
#  '20.0L',
#  '20.0M',
#  '20.0N',
#  '20.0O',
#  '20.0P',
#  '20.0Q',
#  '20.0R',
#  '20.0S',
#  '20.0T',
#  '20.0U',
#  '20.0V',
#  '20.0W',
#  '20.0X',
#  '20.0Y',
#  '21.0A',
#  '21.0B',
#  '21.0C',
#  '21.0D',
#  '21.0E',
#  '21.0F',
#  '21.0G',
#  '21.0H',
#  '21.0I',
#  '21.0J',
#  '21.0K',
#  '21.0L',
#  '21.0M',
#  '21.0N',
#  '21.0O',
#  '21.0P',
#  '21.0Q',
#  '21.0R',
#  '21.0S',
#  '21.0T',
#  '21.0U',
#  '21.0V',
#  '21.0W',
#  '21.0X',
#  '22.0A',
#  '22.0B',
#  '22.0D',
#  '22.0E',
#  '22.0F',
#  '22.0G',
#  '22.0H',
#  '22.0I',
#  '22.0J',
#  '22.0K',
#  '22.0L',
#  '22.0M',
#  '22.0N',
#  '22.0O',
#  '22.0P',
#  '22.0Q',
#  '22.0R',
#  '22.0S',
#  '22.0T',
#  '22.0U',
#  '22.0V',
#  '22.0W',
#  '22.0X',
#  '22.0Y',
#  '23.0F',
#  '23.0G',
#  '23.0H',
#  '23.0I',
#  '23.0J',
#  '23.0K',
#  '23.0L',
#  '23.0M',
#  '23.0N',
#  '23.0O',
#  '23.0P',
#  '23.0Q',
#  '23.0R',
#  '23.0S',
#  '23.0T',
#  '23.0U',
#  '23.0V',
#  '23.0W',
#  '23.0X',
#  '23.0Y',
#  '24.0G',
#  '24.0H',
#  '24.0I',
#  '24.0J',
#  '24.0K',
#  '24.0L',
#  '24.0M',
#  '24.0N',
#  '24.0O',
#  '24.0P',
#  '24.0Q',
#  '24.0R',
#  '24.0S',
#  '24.0T',
#  '24.0U',
#  '24.0V',
#  '24.0W',
#  '25.0G',
#  '25.0H',
#  '25.0I',
#  '25.0J',
#  '25.0K',
#  '25.0L',
#  '25.0P',
#  '25.0Q',
#  '26.0G',
#  '3.0E',
#  '3.0F',
#  '3.0G',
#  '3.0H',
#  '3.0I',
#  '3.0J',
#  '3.0K',
#  '3.0L',
#  '3.0M',
#  '3.0N',
#  '3.0O',
#  '3.0P',
#  '4.0E',
#  '4.0F',
#  '4.0G',
#  '4.0H',
#  '4.0I',
#  '4.0J',
#  '4.0K',
#  '4.0L',
#  '4.0M',
#  '4.0N',
#  '4.0O',
#  '4.0P',
#  '4.0Q',
#  '5.0E',
#  '5.0F',
#  '5.0G',
#  '5.0H',
#  '5.0I',
#  '5.0J',
#  '5.0K',
#  '5.0L',
#  '5.0M',
#  '5.0N',
#  '5.0O',
#  '5.0P',
#  '5.0Q',
#  '6.0E',
#  '6.0F',
#  '6.0G',
#  '6.0H',
#  '6.0I',
#  '6.0J',
#  '6.0K',
#  '6.0L',
#  '6.0M',
#  '6.0N',
#  '6.0O',
#  '6.0P',
#  '7.0E',
#  '7.0F',
#  '7.0G',
#  '7.0H',
#  '7.0I',
#  '7.0J',
#  '7.0K',
#  '7.0L',
#  '7.0M',
#  '7.0N',
#  '7.0O',
#  '8.0E',
#  '8.0F',
#  '8.0G',
#  '8.0H',
#  '8.0I',
#  '8.0J',
#  '8.0K',
#  '8.0L',
#  '8.0M',
#  '8.0N',
#  '8.0O',
#  '9.0C',
#  '9.0D',
#  '9.0E',
#  '9.0F',
#  '9.0G',
#  '9.0H',
#  '9.0I',
#  '9.0J',
#  '9.0K',
#  '9.0L',
#  '9.0M',
#  '9.0N',
#  '9.0O',
#  '9.0P',
#  '9.0Q',
#  '9.0S',
#  '9.0T',
#  '9.0U',
#  '9.0V']

# %%
#list(subgraphs['A4.0'].nodes(data=True))

# %%
#type(list(subgraphs['4.0A'].nodes(data=True))[0][1]['pos'])

# %%
#pos=nx.get_node_attributes(subgraphs['4.0A'],'pos')

# %%
fig = plt.figure()
nx.draw(subgraphs['4.0A'], node_size=2, node_color='white', edge_color='silver')
fig.set_facecolor("#00000F")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-88d168d92d22> in <module>
#       1 fig = plt.figure()
# ----> 2 nx.draw(subgraphs['4.0A'], node_size=2, node_color='white', edge_color='silver')
#       3 fig.set_facecolor("#00000F")
#
# KeyError: '4.0A'

# %%
fig = plt.figure()
nx.draw(subgraphs['4.0A'], pos, node_size=2, node_color='white', edge_color='silver')
fig.set_facecolor("#00000F")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-4697123c8b07> in <module>
#       1 fig = plt.figure()
# ----> 2 nx.draw(subgraphs['4.0A'], pos, node_size=2, node_color='white', edge_color='silver')
#       3 fig.set_facecolor("#00000F")
#
# KeyError: '4.0A'

# %%
all_grid_refs = []

for i in range(26):
    for j in range(26):
        x = j
        y =  chr(ord('A') + int(i))
        all_grid_refs.append(f'{x}.0{y}')

# %%
all_grid_refs
# Out:
# ['0.0A',
#  '1.0A',
#  '2.0A',
#  '3.0A',
#  '4.0A',
#  '5.0A',
#  '6.0A',
#  '7.0A',
#  '8.0A',
#  '9.0A',
#  '10.0A',
#  '11.0A',
#  '12.0A',
#  '13.0A',
#  '14.0A',
#  '15.0A',
#  '16.0A',
#  '17.0A',
#  '18.0A',
#  '19.0A',
#  '20.0A',
#  '21.0A',
#  '22.0A',
#  '23.0A',
#  '24.0A',
#  '25.0A',
#  '0.0B',
#  '1.0B',
#  '2.0B',
#  '3.0B',
#  '4.0B',
#  '5.0B',
#  '6.0B',
#  '7.0B',
#  '8.0B',
#  '9.0B',
#  '10.0B',
#  '11.0B',
#  '12.0B',
#  '13.0B',
#  '14.0B',
#  '15.0B',
#  '16.0B',
#  '17.0B',
#  '18.0B',
#  '19.0B',
#  '20.0B',
#  '21.0B',
#  '22.0B',
#  '23.0B',
#  '24.0B',
#  '25.0B',
#  '0.0C',
#  '1.0C',
#  '2.0C',
#  '3.0C',
#  '4.0C',
#  '5.0C',
#  '6.0C',
#  '7.0C',
#  '8.0C',
#  '9.0C',
#  '10.0C',
#  '11.0C',
#  '12.0C',
#  '13.0C',
#  '14.0C',
#  '15.0C',
#  '16.0C',
#  '17.0C',
#  '18.0C',
#  '19.0C',
#  '20.0C',
#  '21.0C',
#  '22.0C',
#  '23.0C',
#  '24.0C',
#  '25.0C',
#  '0.0D',
#  '1.0D',
#  '2.0D',
#  '3.0D',
#  '4.0D',
#  '5.0D',
#  '6.0D',
#  '7.0D',
#  '8.0D',
#  '9.0D',
#  '10.0D',
#  '11.0D',
#  '12.0D',
#  '13.0D',
#  '14.0D',
#  '15.0D',
#  '16.0D',
#  '17.0D',
#  '18.0D',
#  '19.0D',
#  '20.0D',
#  '21.0D',
#  '22.0D',
#  '23.0D',
#  '24.0D',
#  '25.0D',
#  '0.0E',
#  '1.0E',
#  '2.0E',
#  '3.0E',
#  '4.0E',
#  '5.0E',
#  '6.0E',
#  '7.0E',
#  '8.0E',
#  '9.0E',
#  '10.0E',
#  '11.0E',
#  '12.0E',
#  '13.0E',
#  '14.0E',
#  '15.0E',
#  '16.0E',
#  '17.0E',
#  '18.0E',
#  '19.0E',
#  '20.0E',
#  '21.0E',
#  '22.0E',
#  '23.0E',
#  '24.0E',
#  '25.0E',
#  '0.0F',
#  '1.0F',
#  '2.0F',
#  '3.0F',
#  '4.0F',
#  '5.0F',
#  '6.0F',
#  '7.0F',
#  '8.0F',
#  '9.0F',
#  '10.0F',
#  '11.0F',
#  '12.0F',
#  '13.0F',
#  '14.0F',
#  '15.0F',
#  '16.0F',
#  '17.0F',
#  '18.0F',
#  '19.0F',
#  '20.0F',
#  '21.0F',
#  '22.0F',
#  '23.0F',
#  '24.0F',
#  '25.0F',
#  '0.0G',
#  '1.0G',
#  '2.0G',
#  '3.0G',
#  '4.0G',
#  '5.0G',
#  '6.0G',
#  '7.0G',
#  '8.0G',
#  '9.0G',
#  '10.0G',
#  '11.0G',
#  '12.0G',
#  '13.0G',
#  '14.0G',
#  '15.0G',
#  '16.0G',
#  '17.0G',
#  '18.0G',
#  '19.0G',
#  '20.0G',
#  '21.0G',
#  '22.0G',
#  '23.0G',
#  '24.0G',
#  '25.0G',
#  '0.0H',
#  '1.0H',
#  '2.0H',
#  '3.0H',
#  '4.0H',
#  '5.0H',
#  '6.0H',
#  '7.0H',
#  '8.0H',
#  '9.0H',
#  '10.0H',
#  '11.0H',
#  '12.0H',
#  '13.0H',
#  '14.0H',
#  '15.0H',
#  '16.0H',
#  '17.0H',
#  '18.0H',
#  '19.0H',
#  '20.0H',
#  '21.0H',
#  '22.0H',
#  '23.0H',
#  '24.0H',
#  '25.0H',
#  '0.0I',
#  '1.0I',
#  '2.0I',
#  '3.0I',
#  '4.0I',
#  '5.0I',
#  '6.0I',
#  '7.0I',
#  '8.0I',
#  '9.0I',
#  '10.0I',
#  '11.0I',
#  '12.0I',
#  '13.0I',
#  '14.0I',
#  '15.0I',
#  '16.0I',
#  '17.0I',
#  '18.0I',
#  '19.0I',
#  '20.0I',
#  '21.0I',
#  '22.0I',
#  '23.0I',
#  '24.0I',
#  '25.0I',
#  '0.0J',
#  '1.0J',
#  '2.0J',
#  '3.0J',
#  '4.0J',
#  '5.0J',
#  '6.0J',
#  '7.0J',
#  '8.0J',
#  '9.0J',
#  '10.0J',
#  '11.0J',
#  '12.0J',
#  '13.0J',
#  '14.0J',
#  '15.0J',
#  '16.0J',
#  '17.0J',
#  '18.0J',
#  '19.0J',
#  '20.0J',
#  '21.0J',
#  '22.0J',
#  '23.0J',
#  '24.0J',
#  '25.0J',
#  '0.0K',
#  '1.0K',
#  '2.0K',
#  '3.0K',
#  '4.0K',
#  '5.0K',
#  '6.0K',
#  '7.0K',
#  '8.0K',
#  '9.0K',
#  '10.0K',
#  '11.0K',
#  '12.0K',
#  '13.0K',
#  '14.0K',
#  '15.0K',
#  '16.0K',
#  '17.0K',
#  '18.0K',
#  '19.0K',
#  '20.0K',
#  '21.0K',
#  '22.0K',
#  '23.0K',
#  '24.0K',
#  '25.0K',
#  '0.0L',
#  '1.0L',
#  '2.0L',
#  '3.0L',
#  '4.0L',
#  '5.0L',
#  '6.0L',
#  '7.0L',
#  '8.0L',
#  '9.0L',
#  '10.0L',
#  '11.0L',
#  '12.0L',
#  '13.0L',
#  '14.0L',
#  '15.0L',
#  '16.0L',
#  '17.0L',
#  '18.0L',
#  '19.0L',
#  '20.0L',
#  '21.0L',
#  '22.0L',
#  '23.0L',
#  '24.0L',
#  '25.0L',
#  '0.0M',
#  '1.0M',
#  '2.0M',
#  '3.0M',
#  '4.0M',
#  '5.0M',
#  '6.0M',
#  '7.0M',
#  '8.0M',
#  '9.0M',
#  '10.0M',
#  '11.0M',
#  '12.0M',
#  '13.0M',
#  '14.0M',
#  '15.0M',
#  '16.0M',
#  '17.0M',
#  '18.0M',
#  '19.0M',
#  '20.0M',
#  '21.0M',
#  '22.0M',
#  '23.0M',
#  '24.0M',
#  '25.0M',
#  '0.0N',
#  '1.0N',
#  '2.0N',
#  '3.0N',
#  '4.0N',
#  '5.0N',
#  '6.0N',
#  '7.0N',
#  '8.0N',
#  '9.0N',
#  '10.0N',
#  '11.0N',
#  '12.0N',
#  '13.0N',
#  '14.0N',
#  '15.0N',
#  '16.0N',
#  '17.0N',
#  '18.0N',
#  '19.0N',
#  '20.0N',
#  '21.0N',
#  '22.0N',
#  '23.0N',
#  '24.0N',
#  '25.0N',
#  '0.0O',
#  '1.0O',
#  '2.0O',
#  '3.0O',
#  '4.0O',
#  '5.0O',
#  '6.0O',
#  '7.0O',
#  '8.0O',
#  '9.0O',
#  '10.0O',
#  '11.0O',
#  '12.0O',
#  '13.0O',
#  '14.0O',
#  '15.0O',
#  '16.0O',
#  '17.0O',
#  '18.0O',
#  '19.0O',
#  '20.0O',
#  '21.0O',
#  '22.0O',
#  '23.0O',
#  '24.0O',
#  '25.0O',
#  '0.0P',
#  '1.0P',
#  '2.0P',
#  '3.0P',
#  '4.0P',
#  '5.0P',
#  '6.0P',
#  '7.0P',
#  '8.0P',
#  '9.0P',
#  '10.0P',
#  '11.0P',
#  '12.0P',
#  '13.0P',
#  '14.0P',
#  '15.0P',
#  '16.0P',
#  '17.0P',
#  '18.0P',
#  '19.0P',
#  '20.0P',
#  '21.0P',
#  '22.0P',
#  '23.0P',
#  '24.0P',
#  '25.0P',
#  '0.0Q',
#  '1.0Q',
#  '2.0Q',
#  '3.0Q',
#  '4.0Q',
#  '5.0Q',
#  '6.0Q',
#  '7.0Q',
#  '8.0Q',
#  '9.0Q',
#  '10.0Q',
#  '11.0Q',
#  '12.0Q',
#  '13.0Q',
#  '14.0Q',
#  '15.0Q',
#  '16.0Q',
#  '17.0Q',
#  '18.0Q',
#  '19.0Q',
#  '20.0Q',
#  '21.0Q',
#  '22.0Q',
#  '23.0Q',
#  '24.0Q',
#  '25.0Q',
#  '0.0R',
#  '1.0R',
#  '2.0R',
#  '3.0R',
#  '4.0R',
#  '5.0R',
#  '6.0R',
#  '7.0R',
#  '8.0R',
#  '9.0R',
#  '10.0R',
#  '11.0R',
#  '12.0R',
#  '13.0R',
#  '14.0R',
#  '15.0R',
#  '16.0R',
#  '17.0R',
#  '18.0R',
#  '19.0R',
#  '20.0R',
#  '21.0R',
#  '22.0R',
#  '23.0R',
#  '24.0R',
#  '25.0R',
#  '0.0S',
#  '1.0S',
#  '2.0S',
#  '3.0S',
#  '4.0S',
#  '5.0S',
#  '6.0S',
#  '7.0S',
#  '8.0S',
#  '9.0S',
#  '10.0S',
#  '11.0S',
#  '12.0S',
#  '13.0S',
#  '14.0S',
#  '15.0S',
#  '16.0S',
#  '17.0S',
#  '18.0S',
#  '19.0S',
#  '20.0S',
#  '21.0S',
#  '22.0S',
#  '23.0S',
#  '24.0S',
#  '25.0S',
#  '0.0T',
#  '1.0T',
#  '2.0T',
#  '3.0T',
#  '4.0T',
#  '5.0T',
#  '6.0T',
#  '7.0T',
#  '8.0T',
#  '9.0T',
#  '10.0T',
#  '11.0T',
#  '12.0T',
#  '13.0T',
#  '14.0T',
#  '15.0T',
#  '16.0T',
#  '17.0T',
#  '18.0T',
#  '19.0T',
#  '20.0T',
#  '21.0T',
#  '22.0T',
#  '23.0T',
#  '24.0T',
#  '25.0T',
#  '0.0U',
#  '1.0U',
#  '2.0U',
#  '3.0U',
#  '4.0U',
#  '5.0U',
#  '6.0U',
#  '7.0U',
#  '8.0U',
#  '9.0U',
#  '10.0U',
#  '11.0U',
#  '12.0U',
#  '13.0U',
#  '14.0U',
#  '15.0U',
#  '16.0U',
#  '17.0U',
#  '18.0U',
#  '19.0U',
#  '20.0U',
#  '21.0U',
#  '22.0U',
#  '23.0U',
#  '24.0U',
#  '25.0U',
#  '0.0V',
#  '1.0V',
#  '2.0V',
#  '3.0V',
#  '4.0V',
#  '5.0V',
#  '6.0V',
#  '7.0V',
#  '8.0V',
#  '9.0V',
#  '10.0V',
#  '11.0V',
#  '12.0V',
#  '13.0V',
#  '14.0V',
#  '15.0V',
#  '16.0V',
#  '17.0V',
#  '18.0V',
#  '19.0V',
#  '20.0V',
#  '21.0V',
#  '22.0V',
#  '23.0V',
#  '24.0V',
#  '25.0V',
#  '0.0W',
#  '1.0W',
#  '2.0W',
#  '3.0W',
#  '4.0W',
#  '5.0W',
#  '6.0W',
#  '7.0W',
#  '8.0W',
#  '9.0W',
#  '10.0W',
#  '11.0W',
#  '12.0W',
#  '13.0W',
#  '14.0W',
#  '15.0W',
#  '16.0W',
#  '17.0W',
#  '18.0W',
#  '19.0W',
#  '20.0W',
#  '21.0W',
#  '22.0W',
#  '23.0W',
#  '24.0W',
#  '25.0W',
#  '0.0X',
#  '1.0X',
#  '2.0X',
#  '3.0X',
#  '4.0X',
#  '5.0X',
#  '6.0X',
#  '7.0X',
#  '8.0X',
#  '9.0X',
#  '10.0X',
#  '11.0X',
#  '12.0X',
#  '13.0X',
#  '14.0X',
#  '15.0X',
#  '16.0X',
#  '17.0X',
#  '18.0X',
#  '19.0X',
#  '20.0X',
#  '21.0X',
#  '22.0X',
#  '23.0X',
#  '24.0X',
#  '25.0X',
#  '0.0Y',
#  '1.0Y',
#  '2.0Y',
#  '3.0Y',
#  '4.0Y',
#  '5.0Y',
#  '6.0Y',
#  '7.0Y',
#  '8.0Y',
#  '9.0Y',
#  '10.0Y',
#  '11.0Y',
#  '12.0Y',
#  '13.0Y',
#  '14.0Y',
#  '15.0Y',
#  '16.0Y',
#  '17.0Y',
#  '18.0Y',
#  '19.0Y',
#  '20.0Y',
#  '21.0Y',
#  '22.0Y',
#  '23.0Y',
#  '24.0Y',
#  '25.0Y',
#  '0.0Z',
#  '1.0Z',
#  '2.0Z',
#  '3.0Z',
#  '4.0Z',
#  '5.0Z',
#  '6.0Z',
#  '7.0Z',
#  '8.0Z',
#  '9.0Z',
#  '10.0Z',
#  '11.0Z',
#  '12.0Z',
#  '13.0Z',
#  '14.0Z',
#  '15.0Z',
#  '16.0Z',
#  '17.0Z',
#  '18.0Z',
#  '19.0Z',
#  '20.0Z',
#  '21.0Z',
#  '22.0Z',
#  '23.0Z',
#  '24.0Z',
#  '25.0Z']

# %%
fig = plt.figure(figsize=(18,12))
for i in grid_refs:
    pos=nx.get_node_attributes(subgraphs[i],'pos')
    nx.draw(subgraphs[i], pos, node_size=2, node_color='white', edge_color='silver')
fig.set_facecolor("#00000F")

# %%
gg = nx.Graph()

# %%
fig, ax = ox.plot_graph(G_drive, node_size=2, node_zorder=3, node_alpha=1, 
                        edge_linewidth=0.25, edge_color='lightblue',edge_alpha=1, figsize=(18,18),close=False, show=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-7c3b5472d7a3> in <module>
# ----> 1 fig, ax = ox.plot_graph(G_drive, node_size=2, node_zorder=3, node_alpha=1,
#       2                         edge_linewidth=0.25, edge_color='lightblue',edge_alpha=1, figsize=(18,18),close=False, show=False)
#
# NameError: name 'ox' is not defined

# %%
fig, axes = plt.subplots(nrows=26, ncols=26, figsize=(18,12))
fig.subplots_adjust(hspace =.000001, wspace=.00001)
ax = axes.flatten()
i=0

for i,j in enumerate(all_grid_refs):
    if j in grid_refs:
        pos = nx.get_node_attributes(subgraphs[j],'pos')
        nx.draw(subgraphs[j], pos, node_size=1, node_color='white', edge_color='silver', ax=ax[i])
        ax[i].set_axis_off()
        i+=1
        fig.set_facecolor("#00000F")
    else:
        nx.draw(gg, ax=ax[i])
        ax[i].set_axis_off()
        fig.set_facecolor("#00000F")
        i+=1

plt.show()

# %%
all_grid_refs[4] in grid_refs
# Out:
# True

# %%
A = nx.adjacency_matrix(subgraphs['A4.0'])

# %%
print(A.todense())
